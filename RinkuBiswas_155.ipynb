# %%
#importing liabraies
import tensorflow as tf
import numpy as np

#step1: Convert data to Numpy array
x=np.array([1,2,3,4],dtype=float)
y=np.array([2,4,6,8],dtype=float)

#step2: Define model using input layer (recommended)
model=tf.keras.Sequential([
    tf.keras.Input(shape=(1,)), #prefered over input_shape in Dense
    tf.keras.layers.Dense(1)
])

#step3: Compile the model
model.compile(optimizer='sgd',loss='mean_squared_error')

#step4: Train the model
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - loss: 9.6594
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 6.7085
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 4.6608
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 3.2400
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 2.2540
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.5699
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.0951
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.7657
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.5370
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3784

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

#step1: Convert data to Numpy array
x=np.array([1,2,3,4],dtype=float)
y=np.array([2,4,6,8],dtype=float)

#Define the model
model=Sequential([
    Dense(1, input_shape=(1,))
])

#Compile the model
model.compile(optimizer='sgd',loss='mse')

#step4: Train the model
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 61.6573
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 42.8210
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 29.7506
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 20.6812
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 14.3879
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 10.0208
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 6.9904
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 4.8874
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 3.4280
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.4151

# %%
import torch
import torch.nn as nn
import torch.optim as optim

#Define a simple  Linear Model
model=nn.Linear(1,1)

#Loss and optimizer
criterion=nn.MSELoss()
optimizer=optim.SGD(model.parameters(),lr=0.01)

#Dummy Data
x=torch.tensor([[1.],[2.],[3.],[4.]])
y=torch.tensor([[2.],[4.],[6.],[8.]])

#Training Loop
for epoch in range(10):
  optimizer.zero_grad()
  outputs=model(x)
  loss=criterion(outputs,y)
  loss.backward()
  optimizer.step()
  print(f"Epoch {epoch+1},loss: {loss.item()}")
# Out:
# Epoch 1,loss: 39.417938232421875
# Epoch 2,loss: 27.370399475097656
# Epoch 3,loss: 19.010757446289062
# Epoch 4,loss: 13.210062026977539
# Epoch 5,loss: 9.184969902038574
# Epoch 6,loss: 6.391931533813477
# Epoch 7,loss: 4.453790664672852
# Epoch 8,loss: 3.1088433265686035
# Epoch 9,loss: 2.1755032539367676
# Epoch 10,loss: 1.527768850326538
