# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout

vocab_size = 10000
max_len = 200

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=vocab_size)

x_train = pad_sequences(x_train, maxlen=max_len)
x_test = pad_sequences(x_test, maxlen=max_len)

model = Sequential([
    Embedding(vocab_size, 128, input_length=max_len),
    LSTM(128),
    Dropout(0.5),
    Dense(1, activation="sigmoid")
])

model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model.summary()

history = model.fit(
    x_train,
    y_train,
    epochs=3,
    batch_size=64,
    validation_split=0.2
)

loss, accuracy = model.evaluate(x_test, y_test)
print("Test Accuracy:", accuracy)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 161s 505ms/step - accuracy: 0.7724 - loss: 0.4640 - val_accuracy: 0.8348 - val_loss: 0.3784
# Epoch 2/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 159s 509ms/step - accuracy: 0.8965 - loss: 0.2637 - val_accuracy: 0.8622 - val_loss: 0.3234
# Epoch 3/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 167s 535ms/step - accuracy: 0.9306 - loss: 0.1876 - val_accuracy: 0.8584 - val_loss: 0.3388
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 80s 102ms/step - accuracy: 0.8567 - loss: 0.3524
# Test Accuracy: 0.856719970703125

# %%
import matplotlib.pyplot as plt

plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.title("LSTM Text Classification Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("LSTM Text Classification Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense

input_texts = [
    "one", "two", "three", "four", "five",
    "six", "seven", "eight", "nine", "ten"
]

target_texts = [
    "\tone\n", "\tdo\n", "\tteen\n", "\tchaar\n", "\tpaanch\n",
    "\tchhe\n", "\tsaat\n", "\taath\n", "\tnau\n", "\tdas\n"
]

input_chars = sorted(list(set("".join(input_texts))))
target_chars = sorted(list(set("".join(target_texts))))

num_encoder_tokens = len(input_chars)
num_decoder_tokens = len(target_chars)

max_encoder_seq_length = max(len(txt) for txt in input_texts)
max_decoder_seq_length = max(len(txt) for txt in target_texts)

input_token_index = dict([(char, i) for i, char in enumerate(input_chars)])
target_token_index = dict([(char, i) for i, char in enumerate(target_chars)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype="float32"
)

decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype="float32"
)

decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype="float32"
)

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0

    for t, char in enumerate(target_text):
        decoder_input_data[i, t, target_token_index[char]] = 1.0

        if t > 0:
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0

latent_dim = 256

encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

encoder_states = [state_h, state_c]

decoder_inputs = Input(shape=(None, num_decoder_tokens))
decoder_lstm = LSTM(
    latent_dim,
    return_sequences=True,
    return_state=True
)

decoder_outputs, _, _ = decoder_lstm(
    decoder_inputs,
    initial_state=encoder_states
)

decoder_dense = Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()

model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=2,
    epochs=300,
    validation_split=0.2
)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, None, 14)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_2       │ (None, None, 14)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, 256),     │    277,504 │ input_layer_1[0]… │
# │                     │ (None, 256),      │            │                   │
# │                     │ (None, 256)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ [(None, None,     │    277,504 │ input_layer_2[0]… │
# │                     │ 256), (None,      │            │ lstm_1[0][1],     │
# │                     │ 256), (None,      │            │ lstm_1[0][2]      │
# │                     │ 256)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, None, 14)  │      3,598 │ lstm_2[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 558,606 (2.13 MB)
#  Trainable params: 558,606 (2.13 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - accuracy: 0.0625 - loss: 1.6451 - val_accuracy: 0.1250 - val_loss: 1.3058
# Epoch 2/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.2188 - loss: 1.6019 - val_accuracy: 0.1875 - val_loss: 1.2897
# Epoch 3/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.2344 - loss: 1.5511 - val_accuracy: 0.2500 - val_loss: 1.2579
# Epoch 4/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.2188 - loss: 1.4565 - val_accuracy: 0.2500 - val_loss: 1.1887
# Epoch 5/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.2188 - loss: 1.3451 - val_accuracy: 0.2500 - val_loss: 1.1940
# Epoch 6/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2500 - loss: 1.3215 - val_accuracy: 0.2500 - val_loss: 1.3510
# Epoch 7/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.2188 - loss: 1.3496 - val_accuracy: 0.2500 - val_loss: 1.4381
# Epoch 8/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2188 - loss: 1.3340 - val_accuracy: 0.2500 - val_loss: 1.4579
# Epoch 9/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.2188 - loss: 1.2921 - val_accuracy: 0.1250 - val_loss: 1.4548
# Epoch 10/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.2188 - loss: 1.2336 - val_accuracy: 0.2500 - val_loss: 1.4227
# Epoch 11/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2188 - loss: 1.1823 - val_accuracy: 0.2500 - val_loss: 1.4389
# Epoch 12/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.2188 - loss: 1.1422 - val_accuracy: 0.2500 - val_loss: 1.4308
# Epoch 13/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2500 - loss: 1.1126 - val_accuracy: 0.2500 - val_loss: 1.4031
# Epoch 14/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.2500 - loss: 1.0792 - val_accuracy: 0.2500 - val_loss: 1.4117
# Epoch 15/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.2656 - loss: 1.0418 - val_accuracy: 0.2500 - val_loss: 1.4086
# Epoch 16/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2812 - loss: 1.0158 - val_accuracy: 0.1250 - val_loss: 1.4608
# Epoch 17/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.2812 - loss: 0.9700 - val_accuracy: 0.1250 - val_loss: 1.4687
# Epoch 18/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.3125 - loss: 0.9188 - val_accuracy: 0.1250 - val_loss: 1.5300
# Epoch 19/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3125 - loss: 0.8730 - val_accuracy: 0.1250 - val_loss: 1.5200
# Epoch 20/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.3594 - loss: 0.8350 - val_accuracy: 0.1250 - val_loss: 1.5995
# Epoch 21/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3594 - loss: 0.7938 - val_accuracy: 0.1250 - val_loss: 1.6160
# Epoch 22/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.3906 - loss: 0.7670 - val_accuracy: 0.1250 - val_loss: 1.5124
# Epoch 23/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4219 - loss: 0.7273 - val_accuracy: 0.1250 - val_loss: 1.5842
# Epoch 24/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4375 - loss: 0.6827 - val_accuracy: 0.1250 - val_loss: 1.6653
# Epoch 25/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4531 - loss: 0.6351 - val_accuracy: 0.1250 - val_loss: 1.6502
# Epoch 26/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4531 - loss: 0.6232 - val_accuracy: 0.1250 - val_loss: 1.5885
# Epoch 27/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4844 - loss: 0.6053 - val_accuracy: 0.1250 - val_loss: 1.7387
# Epoch 28/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4375 - loss: 0.6249 - val_accuracy: 0.0000e+00 - val_loss: 1.8361
# Epoch 29/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4844 - loss: 0.5690 - val_accuracy: 0.1250 - val_loss: 1.5072
# Epoch 30/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4688 - loss: 0.6142 - val_accuracy: 0.1250 - val_loss: 1.4939
# Epoch 31/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5156 - loss: 0.5772 - val_accuracy: 0.1250 - val_loss: 1.5591
# Epoch 32/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5156 - loss: 0.5115 - val_accuracy: 0.1250 - val_loss: 1.7118
# Epoch 33/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.5312 - loss: 0.5080 - val_accuracy: 0.1250 - val_loss: 1.7406
# Epoch 34/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.5000 - loss: 0.4844 - val_accuracy: 0.0625 - val_loss: 1.7715
# Epoch 35/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5156 - loss: 0.4509 - val_accuracy: 0.1250 - val_loss: 1.8156
# Epoch 36/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.5312 - loss: 0.4500 - val_accuracy: 0.0625 - val_loss: 1.9066
# Epoch 37/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5156 - loss: 0.4141 - val_accuracy: 0.0625 - val_loss: 1.8472
# Epoch 38/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.5312 - loss: 0.4756 - val_accuracy: 0.0625 - val_loss: 1.7793
# Epoch 39/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5312 - loss: 0.4545 - val_accuracy: 0.0625 - val_loss: 1.7944
# Epoch 40/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5469 - loss: 0.4226 - val_accuracy: 0.1250 - val_loss: 1.8691
# Epoch 41/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5156 - loss: 0.4508 - val_accuracy: 0.0625 - val_loss: 1.9141
# Epoch 42/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5312 - loss: 0.4066 - val_accuracy: 0.1250 - val_loss: 1.7849
# Epoch 43/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5625 - loss: 0.3941 - val_accuracy: 0.1250 - val_loss: 1.7477
# Epoch 44/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5781 - loss: 0.3934 - val_accuracy: 0.0625 - val_loss: 1.8545
# Epoch 45/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5781 - loss: 0.3720 - val_accuracy: 0.0625 - val_loss: 1.8809
# Epoch 46/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5938 - loss: 0.3589 - val_accuracy: 0.1250 - val_loss: 1.7923
# Epoch 47/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5938 - loss: 0.3609 - val_accuracy: 0.1250 - val_loss: 1.8290
# Epoch 48/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5781 - loss: 0.3364 - val_accuracy: 0.0625 - val_loss: 1.9078
# Epoch 49/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5938 - loss: 0.3274 - val_accuracy: 0.1250 - val_loss: 1.8909
# Epoch 50/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6094 - loss: 0.3276 - val_accuracy: 0.1250 - val_loss: 1.8589
# Epoch 51/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6094 - loss: 0.3301 - val_accuracy: 0.0625 - val_loss: 1.9104
# Epoch 52/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6094 - loss: 0.3191 - val_accuracy: 0.0625 - val_loss: 1.9144
# Epoch 53/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6094 - loss: 0.3146 - val_accuracy: 0.1250 - val_loss: 1.8809
# Epoch 54/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6094 - loss: 0.3091 - val_accuracy: 0.1250 - val_loss: 1.8631
# Epoch 55/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6094 - loss: 0.3086 - val_accuracy: 0.1250 - val_loss: 1.9081
# Epoch 56/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6094 - loss: 0.3074 - val_accuracy: 0.0625 - val_loss: 1.9085
# Epoch 57/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.3037 - val_accuracy: 0.1250 - val_loss: 1.8816
# Epoch 58/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 0.3034 - val_accuracy: 0.1250 - val_loss: 1.8973
# Epoch 59/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6094 - loss: 0.3004 - val_accuracy: 0.1250 - val_loss: 1.9313
# Epoch 60/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2923 - val_accuracy: 0.1250 - val_loss: 1.9012
# Epoch 61/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.3046 - val_accuracy: 0.1250 - val_loss: 1.8938
# Epoch 62/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.2901 - val_accuracy: 0.0625 - val_loss: 1.9224
# Epoch 63/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 0.2908 - val_accuracy: 0.1250 - val_loss: 1.8673
# Epoch 64/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6094 - loss: 0.2909 - val_accuracy: 0.1250 - val_loss: 1.9205
# Epoch 65/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2830 - val_accuracy: 0.1250 - val_loss: 1.9261
# Epoch 66/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2916 - val_accuracy: 0.1250 - val_loss: 1.9566
# Epoch 67/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6250 - loss: 0.2806 - val_accuracy: 0.1250 - val_loss: 1.9117
# Epoch 68/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6250 - loss: 0.2832 - val_accuracy: 0.1250 - val_loss: 1.8698
# Epoch 69/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2888 - val_accuracy: 0.0625 - val_loss: 1.9358
# Epoch 70/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6250 - loss: 0.2762 - val_accuracy: 0.1250 - val_loss: 1.9312
# Epoch 71/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2832 - val_accuracy: 0.1250 - val_loss: 1.9156
# Epoch 72/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.2698 - val_accuracy: 0.1250 - val_loss: 1.9113
# Epoch 73/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 0.2764 - val_accuracy: 0.1250 - val_loss: 1.9116
# Epoch 74/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 0.2748 - val_accuracy: 0.1250 - val_loss: 1.9377
# Epoch 75/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2733 - val_accuracy: 0.1250 - val_loss: 1.9560
# Epoch 76/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2766 - val_accuracy: 0.1250 - val_loss: 1.9216
# Epoch 77/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6250 - loss: 0.2642 - val_accuracy: 0.1250 - val_loss: 1.9001
# Epoch 78/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2820 - val_accuracy: 0.0625 - val_loss: 1.9464
# Epoch 79/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 0.2643 - val_accuracy: 0.1250 - val_loss: 1.9442
# Epoch 80/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2792 - val_accuracy: 0.1250 - val_loss: 1.8871
# Epoch 81/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2677 - val_accuracy: 0.0625 - val_loss: 2.0661
# Epoch 82/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6094 - loss: 0.2915 - val_accuracy: 0.1250 - val_loss: 1.8073
# Epoch 83/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2842 - val_accuracy: 0.0625 - val_loss: 1.9827
# Epoch 84/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 0.2895 - val_accuracy: 0.0625 - val_loss: 1.9647
# Epoch 85/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2788 - val_accuracy: 0.1250 - val_loss: 1.8481
# Epoch 86/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6094 - loss: 0.2839 - val_accuracy: 0.1250 - val_loss: 1.9172
# Epoch 87/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6250 - loss: 0.2794 - val_accuracy: 0.0625 - val_loss: 1.9998
# Epoch 88/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6094 - loss: 0.2659 - val_accuracy: 0.1250 - val_loss: 1.9846
# Epoch 89/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6094 - loss: 0.2920 - val_accuracy: 0.1250 - val_loss: 1.8979
# Epoch 90/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5938 - loss: 0.3263 - val_accuracy: 0.1250 - val_loss: 1.8464
# Epoch 91/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5781 - loss: 0.3085 - val_accuracy: 0.1250 - val_loss: 1.9566
# Epoch 92/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6094 - loss: 0.3015 - val_accuracy: 0.1250 - val_loss: 2.0492
# Epoch 93/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5938 - loss: 0.3205 - val_accuracy: 0.0625 - val_loss: 2.1002
# Epoch 94/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5781 - loss: 0.2835 - val_accuracy: 0.1250 - val_loss: 1.9932
# Epoch 95/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.6094 - loss: 0.2816 - val_accuracy: 0.1250 - val_loss: 1.8679
# Epoch 96/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2705 - val_accuracy: 0.1250 - val_loss: 1.8487
# Epoch 97/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6250 - loss: 0.2586 - val_accuracy: 0.1250 - val_loss: 1.9152
# Epoch 98/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 0.2617 - val_accuracy: 0.1250 - val_loss: 1.9735
# Epoch 99/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2565 - val_accuracy: 0.1250 - val_loss: 1.9803
# Epoch 100/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2540 - val_accuracy: 0.1250 - val_loss: 1.9614
# Epoch 101/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2556 - val_accuracy: 0.1250 - val_loss: 1.9489
# Epoch 102/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6250 - loss: 0.2513 - val_accuracy: 0.1250 - val_loss: 1.9424
# Epoch 103/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 0.2522 - val_accuracy: 0.1250 - val_loss: 1.9241
# Epoch 104/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 0.2545 - val_accuracy: 0.1250 - val_loss: 1.9298
# Epoch 105/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2492 - val_accuracy: 0.1250 - val_loss: 1.9453
# Epoch 106/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2463 - val_accuracy: 0.1250 - val_loss: 1.9426
# Epoch 107/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2480 - val_accuracy: 0.1250 - val_loss: 1.9270
# Epoch 108/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 0.2485 - val_accuracy: 0.1250 - val_loss: 1.9275
# Epoch 109/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2455 - val_accuracy: 0.1250 - val_loss: 1.9587
# Epoch 110/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2435 - val_accuracy: 0.1250 - val_loss: 1.9528
# Epoch 111/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2454 - val_accuracy: 0.1250 - val_loss: 1.9353
# Epoch 112/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2457 - val_accuracy: 0.1250 - val_loss: 1.9375
# Epoch 113/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2440 - val_accuracy: 0.1250 - val_loss: 1.9451
# Epoch 114/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2425 - val_accuracy: 0.1250 - val_loss: 1.9422
# Epoch 115/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6250 - loss: 0.2456 - val_accuracy: 0.1250 - val_loss: 1.9482
# Epoch 116/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2428 - val_accuracy: 0.1250 - val_loss: 1.9523
# Epoch 117/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6250 - loss: 0.2423 - val_accuracy: 0.1250 - val_loss: 1.9406
# Epoch 118/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6250 - loss: 0.2425 - val_accuracy: 0.1250 - val_loss: 1.9397
# Epoch 119/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6250 - loss: 0.2397 - val_accuracy: 0.1250 - val_loss: 1.9462
# Epoch 120/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2387 - val_accuracy: 0.1250 - val_loss: 1.9522
# Epoch 121/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2379 - val_accuracy: 0.1250 - val_loss: 1.9519
# Epoch 122/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6250 - loss: 0.2380 - val_accuracy: 0.1250 - val_loss: 1.9486
# Epoch 123/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2390 - val_accuracy: 0.1250 - val_loss: 1.9566
# Epoch 124/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2380 - val_accuracy: 0.1250 - val_loss: 1.9499
# Epoch 125/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2382 - val_accuracy: 0.1250 - val_loss: 1.9441
# Epoch 126/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6250 - loss: 0.2378 - val_accuracy: 0.1250 - val_loss: 1.9616
# Epoch 127/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6250 - loss: 0.2350 - val_accuracy: 0.1250 - val_loss: 1.9587
# Epoch 128/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2374 - val_accuracy: 0.1250 - val_loss: 1.9496
# Epoch 129/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6250 - loss: 0.2329 - val_accuracy: 0.1250 - val_loss: 1.9702
# Epoch 130/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2334 - val_accuracy: 0.1250 - val_loss: 1.9562
# Epoch 131/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6250 - loss: 0.2373 - val_accuracy: 0.1250 - val_loss: 1.9431
# Epoch 132/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2291 - val_accuracy: 0.1250 - val_loss: 1.9600
# Epoch 133/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2349 - val_accuracy: 0.1250 - val_loss: 1.9634
# Epoch 134/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2328 - val_accuracy: 0.1250 - val_loss: 1.9490
# Epoch 135/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2308 - val_accuracy: 0.1250 - val_loss: 1.9595
# Epoch 136/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6250 - loss: 0.2334 - val_accuracy: 0.1250 - val_loss: 1.9749
# Epoch 137/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2290 - val_accuracy: 0.1250 - val_loss: 1.9393
# Epoch 138/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2334 - val_accuracy: 0.1250 - val_loss: 1.9546
# Epoch 139/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2280 - val_accuracy: 0.1250 - val_loss: 1.9661
# Epoch 140/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2237 - val_accuracy: 0.1250 - val_loss: 1.9470
# Epoch 141/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6250 - loss: 0.2363 - val_accuracy: 0.1250 - val_loss: 1.9617
# Epoch 142/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6250 - loss: 0.2285 - val_accuracy: 0.1250 - val_loss: 1.9526
# Epoch 143/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6250 - loss: 0.2311 - val_accuracy: 0.1250 - val_loss: 1.9441
# Epoch 144/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.6250 - loss: 0.2296 - val_accuracy: 0.1250 - val_loss: 1.9555
# Epoch 145/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.6250 - loss: 0.2251 - val_accuracy: 0.1250 - val_loss: 1.9383
# Epoch 146/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6250 - loss: 0.2315 - val_accuracy: 0.1250 - val_loss: 1.9655
# Epoch 147/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6250 - loss: 0.2234 - val_accuracy: 0.1250 - val_loss: 1.9504
# Epoch 148/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6250 - loss: 0.2268 - val_accuracy: 0.1250 - val_loss: 1.9422
# Epoch 149/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.2250 - val_accuracy: 0.1250 - val_loss: 1.9606
# Epoch 150/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6250 - loss: 0.2235 - val_accuracy: 0.1250 - val_loss: 1.9514
# Epoch 151/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6250 - loss: 0.2269 - val_accuracy: 0.1250 - val_loss: 1.9529
# Epoch 152/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2245 - val_accuracy: 0.1250 - val_loss: 1.9510
# Epoch 153/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2225 - val_accuracy: 0.1250 - val_loss: 1.9507
# Epoch 154/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6250 - loss: 0.2226 - val_accuracy: 0.1250 - val_loss: 1.9510
# Epoch 155/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2228 - val_accuracy: 0.1250 - val_loss: 1.9448
# Epoch 156/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2254 - val_accuracy: 0.1250 - val_loss: 1.9533
# Epoch 157/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2241 - val_accuracy: 0.1250 - val_loss: 1.9497
# Epoch 158/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2250 - val_accuracy: 0.1250 - val_loss: 1.9456
# Epoch 159/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.2204 - val_accuracy: 0.1250 - val_loss: 1.9467
# Epoch 160/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2218 - val_accuracy: 0.1250 - val_loss: 1.9369
# Epoch 161/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 0.2195 - val_accuracy: 0.1250 - val_loss: 1.9361
# Epoch 162/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2181 - val_accuracy: 0.1250 - val_loss: 1.9506
# Epoch 163/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2232 - val_accuracy: 0.1250 - val_loss: 1.9523
# Epoch 164/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.2173 - val_accuracy: 0.1250 - val_loss: 1.9374
# Epoch 165/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2226 - val_accuracy: 0.1250 - val_loss: 1.9456
# Epoch 166/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2204 - val_accuracy: 0.1250 - val_loss: 1.9647
# Epoch 167/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2140 - val_accuracy: 0.1250 - val_loss: 1.9093
# Epoch 168/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2267 - val_accuracy: 0.1250 - val_loss: 1.9277
# Epoch 169/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2159 - val_accuracy: 0.1250 - val_loss: 1.9555
# Epoch 170/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2249 - val_accuracy: 0.1250 - val_loss: 1.9189
# Epoch 171/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2181 - val_accuracy: 0.1250 - val_loss: 1.9012
# Epoch 172/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2184 - val_accuracy: 0.0625 - val_loss: 1.9950
# Epoch 173/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2198 - val_accuracy: 0.1250 - val_loss: 1.9066
# Epoch 174/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2117 - val_accuracy: 0.1250 - val_loss: 1.9142
# Epoch 175/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2211 - val_accuracy: 0.1250 - val_loss: 1.9239
# Epoch 176/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2133 - val_accuracy: 0.1250 - val_loss: 1.9505
# Epoch 177/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2199 - val_accuracy: 0.1250 - val_loss: 1.9499
# Epoch 178/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6250 - loss: 0.2141 - val_accuracy: 0.1250 - val_loss: 1.9379
# Epoch 179/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2112 - val_accuracy: 0.1250 - val_loss: 1.8497
# Epoch 180/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2257 - val_accuracy: 0.0625 - val_loss: 2.0123
# Epoch 181/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2091 - val_accuracy: 0.0625 - val_loss: 1.9912
# Epoch 182/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2168 - val_accuracy: 0.1250 - val_loss: 1.9441
# Epoch 183/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2144 - val_accuracy: 0.1250 - val_loss: 1.8863
# Epoch 184/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6250 - loss: 0.2148 - val_accuracy: 0.0625 - val_loss: 1.9749
# Epoch 185/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 0.2159 - val_accuracy: 0.0625 - val_loss: 1.9710
# Epoch 186/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2105 - val_accuracy: 0.1250 - val_loss: 1.9307
# Epoch 187/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2181 - val_accuracy: 0.1250 - val_loss: 1.9353
# Epoch 188/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2099 - val_accuracy: 0.0625 - val_loss: 1.9823
# Epoch 189/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2102 - val_accuracy: 0.1250 - val_loss: 1.9388
# Epoch 190/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2126 - val_accuracy: 0.1250 - val_loss: 1.9500
# Epoch 191/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2075 - val_accuracy: 0.1250 - val_loss: 1.9419
# Epoch 192/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2128 - val_accuracy: 0.1250 - val_loss: 1.9331
# Epoch 193/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2129 - val_accuracy: 0.1250 - val_loss: 1.9494
# Epoch 194/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2094 - val_accuracy: 0.1250 - val_loss: 1.9733
# Epoch 195/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6250 - loss: 0.2128 - val_accuracy: 0.1250 - val_loss: 1.9390
# Epoch 196/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6250 - loss: 0.2066 - val_accuracy: 0.1250 - val_loss: 1.9277
# Epoch 197/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6250 - loss: 0.2072 - val_accuracy: 0.1250 - val_loss: 1.9535
# Epoch 198/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6250 - loss: 0.2128 - val_accuracy: 0.1250 - val_loss: 1.9485
# Epoch 199/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6250 - loss: 0.2038 - val_accuracy: 0.1250 - val_loss: 1.9376
# Epoch 200/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6250 - loss: 0.2095 - val_accuracy: 0.1250 - val_loss: 1.9336
# Epoch 201/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.6250 - loss: 0.2083 - val_accuracy: 0.0625 - val_loss: 2.0458
# Epoch 202/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2053 - val_accuracy: 0.1250 - val_loss: 1.9428
# Epoch 203/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.2198 - val_accuracy: 0.1250 - val_loss: 1.8584
# Epoch 204/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.1976 - val_accuracy: 0.0625 - val_loss: 2.0038
# Epoch 205/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6094 - loss: 0.2197 - val_accuracy: 0.1250 - val_loss: 1.9427
# Epoch 206/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 0.2055 - val_accuracy: 0.1250 - val_loss: 1.9204
# Epoch 207/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2063 - val_accuracy: 0.0625 - val_loss: 2.0095
# Epoch 208/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6250 - loss: 0.2071 - val_accuracy: 0.1250 - val_loss: 2.0043
# Epoch 209/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2029 - val_accuracy: 0.1250 - val_loss: 1.9295
# Epoch 210/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2136 - val_accuracy: 0.1250 - val_loss: 1.9383
# Epoch 211/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2012 - val_accuracy: 0.0625 - val_loss: 2.0123
# Epoch 212/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2064 - val_accuracy: 0.1250 - val_loss: 1.8891
# Epoch 213/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.2118 - val_accuracy: 0.1250 - val_loss: 1.8912
# Epoch 214/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2033 - val_accuracy: 0.0625 - val_loss: 1.9940
# Epoch 215/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2179 - val_accuracy: 0.0625 - val_loss: 2.0172
# Epoch 216/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.1999 - val_accuracy: 0.1250 - val_loss: 1.9349
# Epoch 217/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2117 - val_accuracy: 0.1250 - val_loss: 1.9055
# Epoch 218/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6250 - loss: 0.2065 - val_accuracy: 0.0625 - val_loss: 2.0305
# Epoch 219/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2018 - val_accuracy: 0.0625 - val_loss: 2.0195
# Epoch 220/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2036 - val_accuracy: 0.1250 - val_loss: 1.9394
# Epoch 221/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.1983 - val_accuracy: 0.1250 - val_loss: 1.9332
# Epoch 222/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2068 - val_accuracy: 0.1250 - val_loss: 1.9638
# Epoch 223/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.2076 - val_accuracy: 0.0625 - val_loss: 2.0185
# Epoch 224/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 0.1986 - val_accuracy: 0.1250 - val_loss: 1.9931
# Epoch 225/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6250 - loss: 0.2028 - val_accuracy: 0.1250 - val_loss: 1.9868
# Epoch 226/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2002 - val_accuracy: 0.1250 - val_loss: 1.9667
# Epoch 227/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.1973 - val_accuracy: 0.1250 - val_loss: 1.9651
# Epoch 228/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6250 - loss: 0.2051 - val_accuracy: 0.1250 - val_loss: 1.9999
# Epoch 229/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.1996 - val_accuracy: 0.0625 - val_loss: 2.0030
# Epoch 230/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2001 - val_accuracy: 0.1250 - val_loss: 1.9693
# Epoch 231/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2025 - val_accuracy: 0.1250 - val_loss: 1.9728
# Epoch 232/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.1957 - val_accuracy: 0.0625 - val_loss: 2.0200
# Epoch 233/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.1983 - val_accuracy: 0.1250 - val_loss: 2.0077
# Epoch 234/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6250 - loss: 0.2022 - val_accuracy: 0.1250 - val_loss: 1.9587
# Epoch 235/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.1937 - val_accuracy: 0.1250 - val_loss: 1.9860
# Epoch 236/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.1994 - val_accuracy: 0.1250 - val_loss: 2.0038
# Epoch 237/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2015 - val_accuracy: 0.1250 - val_loss: 1.9866
# Epoch 238/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.1985 - val_accuracy: 0.1250 - val_loss: 1.9666
# Epoch 239/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.1993 - val_accuracy: 0.1250 - val_loss: 2.0010
# Epoch 240/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.1952 - val_accuracy: 0.1250 - val_loss: 2.0017
# Epoch 241/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.1954 - val_accuracy: 0.1250 - val_loss: 1.9635
# Epoch 242/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.1991 - val_accuracy: 0.1250 - val_loss: 1.9602
# Epoch 243/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.1923 - val_accuracy: 0.0625 - val_loss: 2.0373
# Epoch 244/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.1963 - val_accuracy: 0.1250 - val_loss: 2.0198
# Epoch 245/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.1960 - val_accuracy: 0.1250 - val_loss: 1.9840
# Epoch 246/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.1946 - val_accuracy: 0.1250 - val_loss: 1.9859
# Epoch 247/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6250 - loss: 0.1963 - val_accuracy: 0.1250 - val_loss: 2.0097
# Epoch 248/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.1930 - val_accuracy: 0.1250 - val_loss: 2.0109
# Epoch 249/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6250 - loss: 0.1947 - val_accuracy: 0.1250 - val_loss: 1.9967
# Epoch 250/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6250 - loss: 0.1931 - val_accuracy: 0.1250 - val_loss: 2.0002
# Epoch 251/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6250 - loss: 0.1912 - val_accuracy: 0.1250 - val_loss: 1.9955
# Epoch 252/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6250 - loss: 0.1959 - val_accuracy: 0.1250 - val_loss: 1.9916
# Epoch 253/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6250 - loss: 0.1944 - val_accuracy: 0.1250 - val_loss: 2.0159
# Epoch 254/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6250 - loss: 0.1912 - val_accuracy: 0.1250 - val_loss: 2.0141
# Epoch 255/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.6250 - loss: 0.1917 - val_accuracy: 0.1250 - val_loss: 1.9904
# Epoch 256/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.6250 - loss: 0.1922 - val_accuracy: 0.1250 - val_loss: 1.9895
# Epoch 257/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6250 - loss: 0.1929 - val_accuracy: 0.1250 - val_loss: 2.0127
# Epoch 258/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.1917 - val_accuracy: 0.1250 - val_loss: 2.0099
# Epoch 259/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.1924 - val_accuracy: 0.1250 - val_loss: 2.0019
# Epoch 260/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.1917 - val_accuracy: 0.1250 - val_loss: 1.9988
# Epoch 261/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6250 - loss: 0.1899 - val_accuracy: 0.1250 - val_loss: 1.9972
# Epoch 262/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.1900 - val_accuracy: 0.1250 - val_loss: 2.0003
# Epoch 263/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.1908 - val_accuracy: 0.1250 - val_loss: 1.9965
# Epoch 264/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.1920 - val_accuracy: 0.1250 - val_loss: 2.0030
# Epoch 265/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.1915 - val_accuracy: 0.1250 - val_loss: 2.0049
# Epoch 266/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.1881 - val_accuracy: 0.1250 - val_loss: 2.0056
# Epoch 267/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6250 - loss: 0.1895 - val_accuracy: 0.1250 - val_loss: 2.0021
# Epoch 268/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.1908 - val_accuracy: 0.1250 - val_loss: 2.0018
# Epoch 269/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6250 - loss: 0.1898 - val_accuracy: 0.1250 - val_loss: 1.9941
# Epoch 270/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.1894 - val_accuracy: 0.1250 - val_loss: 1.9987
# Epoch 271/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6250 - loss: 0.1896 - val_accuracy: 0.1250 - val_loss: 1.9990
# Epoch 272/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.1884 - val_accuracy: 0.1250 - val_loss: 2.0019
# Epoch 273/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.1873 - val_accuracy: 0.1250 - val_loss: 2.0035
# Epoch 274/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6250 - loss: 0.1883 - val_accuracy: 0.1250 - val_loss: 1.9986
# Epoch 275/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.1881 - val_accuracy: 0.1250 - val_loss: 2.0029
# Epoch 276/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.1878 - val_accuracy: 0.1250 - val_loss: 1.9999
# Epoch 277/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.1892 - val_accuracy: 0.1250 - val_loss: 2.0014
# Epoch 278/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.1877 - val_accuracy: 0.1250 - val_loss: 2.0041
# Epoch 279/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.1881 - val_accuracy: 0.1250 - val_loss: 1.9909
# Epoch 280/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6250 - loss: 0.1869 - val_accuracy: 0.1250 - val_loss: 2.0002
# Epoch 281/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.1864 - val_accuracy: 0.1250 - val_loss: 2.0063
# Epoch 282/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.1881 - val_accuracy: 0.1250 - val_loss: 2.0067
# Epoch 283/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.1861 - val_accuracy: 0.1250 - val_loss: 1.9898
# Epoch 284/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.1866 - val_accuracy: 0.1250 - val_loss: 1.9867
# Epoch 285/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.1868 - val_accuracy: 0.1250 - val_loss: 1.9913
# Epoch 286/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6250 - loss: 0.1845 - val_accuracy: 0.1250 - val_loss: 2.0051
# Epoch 287/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.1863 - val_accuracy: 0.1250 - val_loss: 1.9993
# Epoch 288/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.1853 - val_accuracy: 0.1250 - val_loss: 1.9915
# Epoch 289/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.1835 - val_accuracy: 0.1250 - val_loss: 1.9938
# Epoch 290/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.1892 - val_accuracy: 0.1250 - val_loss: 2.0129
# Epoch 291/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.1839 - val_accuracy: 0.1250 - val_loss: 1.9967
# Epoch 292/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.1848 - val_accuracy: 0.1250 - val_loss: 1.9789
# Epoch 293/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6250 - loss: 0.1851 - val_accuracy: 0.1250 - val_loss: 1.9966
# Epoch 294/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.1832 - val_accuracy: 0.1250 - val_loss: 1.9892
# Epoch 295/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.1844 - val_accuracy: 0.1250 - val_loss: 1.9947
# Epoch 296/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.1861 - val_accuracy: 0.1250 - val_loss: 1.9990
# Epoch 297/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6250 - loss: 0.1833 - val_accuracy: 0.1250 - val_loss: 1.9837
# Epoch 298/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.1831 - val_accuracy: 0.1250 - val_loss: 1.9741
# Epoch 299/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.1854 - val_accuracy: 0.1250 - val_loss: 1.9981
# Epoch 300/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.1832 - val_accuracy: 0.1250 - val_loss: 1.9947

# %%
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs,
    initial_state=decoder_states_inputs
)

decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)

decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states
)

reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())

def decode_sequence(input_seq):
    states_value = encoder_model.predict(input_seq)

    target_seq = np.zeros((1, 1, num_decoder_tokens))
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    decoded_sentence = ""

    while True:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value
        )

        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]

        decoded_sentence += sampled_char

        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            break

        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        states_value = [h, c]

    return decoded_sentence

for seq_index in range(10):
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)

    print("Input:", input_texts[seq_index])
    print("Predicted Output:", decoded_sentence)
    print()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Input: one
# Predicted Output: one
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Input: two
# Predicted Output: do
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Input: three
# Predicted Output: teen
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Input: four
# Predicted Output: chaar
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Input: five
# Predicted Output: paanch
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Input: six
# Predicted Output: chhe
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Input: seven
# Predicted Output: saat
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Input: eight
# Predicted Output: aath
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Input: nine
# Predicted Output: one
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Input: ten
# Predicted Output: tee
